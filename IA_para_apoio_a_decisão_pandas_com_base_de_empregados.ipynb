# %% [markdown]
# # Vamos por a mão na massa!

# %% [markdown]
# # Tópicos
# - Importação de um conjunto de dados
# - Sumarização/Informações dos Dados
# - Limpeza dos Dados
# - Consulta de Dados
# - Visualização dos Dados

# %% [markdown]
# ## Importação dos dados

# %%
import pandas as pd
dados = pd.read_csv("https://media.geeksforgeeks.org/wp-content/uploads/employees.csv")

# %% [markdown]
# ## Visualização dos dados

# %%
# visualizando o máximo de registros que o pandas pode nos mostrar
dados
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
# visualizando apenas os primeiros 5 registros
dados.head(5)
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
# visualizando os últimos 10 registros
dados.tail(10)
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 990      Robin  Female   7/24/1987         1:35 PM  100765   10.982
# 991       Rose  Female   8/25/2002         5:12 AM  134505   11.051
# 992    Anthony    Male  10/16/2011         8:35 AM  112769   11.625
# 993       Tina  Female   5/15/1997         3:53 PM   56450   19.040
# 994     George    Male   6/21/2013         5:47 PM   98874    4.479
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 990              True       Client Services
# 991              True             Marketing
# 992              True               Finance
# ...

# %%
# visualizando um intervalo de registros
dados.loc[5:9]
# Out:
#   First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 5     Dennis    Male   4/18/1987         1:35 AM  115163   10.125
# 6       Ruby  Female   8/17/1987         4:20 PM   65476   10.012
# 7        NaN  Female   7/20/2015        10:43 AM   45906   11.598
# 8     Angela  Female  11/22/2005         6:29 AM   95570   18.523
# 9    Frances  Female    8/8/2002         6:51 AM  139852    7.524
#
#   Senior Management                  Team
# 5             False                 Legal
# 6              True               Product
# 7               NaN               Finance
# 8              True           Engineering
# 9              True  Business Development

# %%
# visualizando determinados registros pelo índice
dados.loc[[5, 9, 11]]
# Out:
#    First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 5      Dennis    Male   4/18/1987         1:35 AM  115163   10.125
# 9     Frances  Female    8/8/2002         6:51 AM  139852    7.524
# 11      Julie  Female  10/26/1997         3:19 PM  102508   12.637
#
#    Senior Management                  Team
# 5              False                 Legal
# 9               True  Business Development
# 11              True                 Legal

# %%
# descrevendo os dados
dados.describe()
# Out:
#               Salary      Bonus %
# count    1000.000000  1000.000000
# mean    90662.181000    10.207555
# std     32923.693342     5.528481
# min     35013.000000     1.015000
# 25%     62613.000000     5.401750
# 50%     90428.000000     9.838500
# 75%    118740.250000    14.838000
# max    149908.000000    19.944000

# %%
# visualizando o maior e menor salário
dados.describe().loc['max', 'Salary'], dados.describe().loc['min', 'Salary']
# Out:
# (149908.0, 35013.0)

# %%
dados["Salary"].max()
# Out:
# 149908

# %%
# visualizando a média de salários empregados
dados.describe().loc['mean', 'Salary']
# Out:
# 90662.181

# %%
dados["Salary"].mean()
# Out:
# 90662.181

# %%
# visualizando a média de salários de empregados do time de Business Development
dados[dados['Team'] == 'Business Development'].describe().loc['mean', 'Salary']
# Out:
# 91866.31683168317

# %%
dados.query('Team == "Business Development"')
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 9      Frances  Female    8/8/2002         6:51 AM  139852    7.524
# 33        Jean  Female  12/18/1993         9:07 AM  119082   16.180
# 36      Rachel  Female   2/16/2009         8:47 PM  142032   12.599
# 38   Stephanie  Female   9/13/1986         1:52 AM   36844    5.574
# 41   Christine     NaN   6/28/2015         1:08 AM   66582   11.308
# ..         ...     ...         ...             ...     ...      ...
# 959     Albert    Male   9/19/1992         2:35 AM   45094    5.850
# 960    Stephen    Male  10/29/1989        11:34 PM   93997   18.093
# 971    Patrick    Male  12/30/2002         2:01 AM   75423    5.368
# 973    Russell    Male   5/10/2013        11:08 PM  137359   11.105
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
#
#     Senior Management                  Team
# 9                True  Business Development
# 33              False  Business Development
# ...

# %%
df = dados[dados["Team"] == "Business Development"]
df = df["Salary"]
df.mean()
# Out:
# 91866.31683168317

# %%
# visualizando quais empregados recebem acima da média
mean = dados.describe().loc['mean', 'Salary']

dados[dados['Salary'] > mean]
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# 5       Dennis    Male   4/18/1987         1:35 AM  115163   10.125
# ..         ...     ...         ...             ...     ...      ...
# 992    Anthony    Male  10/16/2011         8:35 AM  112769   11.625
# 994     George    Male   6/21/2013         5:47 PM   98874    4.479
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management             Team
# 0                True        Marketing
# 2               False          Finance
# ...

# %% [markdown]
# <center><h1>Vamos fazer uma limpeza nos dados</h1></center>
#
# ---

# %% [markdown]
# Há registros nulos?? (SIM). Faça as seguintes correções nos dados
#
# - Se não tem informações do Gender (Sexo -masculino ou feminino), exclua o - registro
# - Se não tem informações de "Senior Management", atribua o valor False;
# - Se não tem informações de "Team", atribua o valor "Sales"
# - Atribua "Unknown" onde o First Name é nulo

# %%
# Verificando onde tem valores nulos
dados.isnull().any()
# Out:
# First Name            True
# Gender                True
# Start Date           False
# Last Login Time      False
# Salary               False
# Bonus %              False
# Senior Management     True
# Team                  True
# dtype: bool

# %%
# Verificando aonde em "Gender" que os valores estão nulos
is_null = dados.isnull()

is_null[is_null['Gender'] ==  True].head(5)
# Out:
#     First Name  Gender  Start Date  Last Login Time  Salary  Bonus %  \
# 20       False    True       False            False   False    False
# 22       False    True       False            False   False    False
# 27       False    True       False            False   False    False
# 31       False    True       False            False   False    False
# 41       False    True       False            False   False    False
#
#     Senior Management   Team
# 20              False  False
# 22              False  False
# 27              False  False
# 31              False  False
# 41              False  False

# %% [markdown]
# ## Vamos às questões

# %% [markdown]
# 1) Se não tem informações do Gender (Sexo -masculino ou feminino), exclua o - registro

# %%
dados.isnull().any()
# Out:
# First Name            True
# Gender                True
# Start Date           False
# Last Login Time      False
# Salary               False
# Bonus %              False
# Senior Management     True
# Team                  True
# dtype: bool

# %%
dados["Gender"]
# Out:
# 0        Male
# 1        Male
# 2      Female
# 3        Male
# 4        Male
#         ...
# 995       NaN
# 996      Male
# 997      Male
# 998      Male
# 999      Male
# Name: Gender, Length: 1000, dtype: object

# %%
len(dados)
# Out:
# 1000

# %%
# Excluindo onde Gender é nulo
dados.dropna(subset = ['Gender'], axis = 0, inplace=True)

# %%
len(dados)
# Out:
# 855

# %% [markdown]
# 2) Se não tem informações de "Senior Management", atribua o valor False;

# %%
# Atribuindo valor False onde Senior Management é nulo
dados['Senior Management'].fillna(False, inplace=True)

# %%
dados[dados["Senior Management"].isnull() == True]
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 7          NaN  Female   7/20/2015        10:43 AM   45906   11.598
# 23         NaN    Male   6/14/2012         4:19 PM  125792    5.042
# 25         NaN    Male   10/8/2012         1:12 AM   37076   18.576
# 32         NaN    Male   8/21/1998         2:27 PM  122340    6.417
# 39         NaN    Male   1/29/2016         2:33 AM  122173    7.797
# 62         NaN  Female   6/12/2007         5:25 PM   58112   19.414
# 116        NaN    Male   6/22/1991         8:58 PM   76189   18.988
# 139        NaN  Female   10/3/1990         1:08 AM  132373   10.527
# 149        NaN  Female   8/17/2014         2:00 PM   86230    8.578
# 157        NaN  Female   7/27/2005         8:32 AM   79536   14.443
# 165        NaN  Female   3/23/2014         1:28 PM   59148    9.061
# 166        NaN  Female    7/9/1991         6:52 PM   42341    7.014
# 186        NaN  Female   2/23/2005         9:50 PM  149654    1.825
# ...

# %%
dados
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male  1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...        ...             ...     ...      ...
# 994     George    Male  6/21/2013         5:47 PM   98874    4.479
# 996    Phillip    Male  1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male  5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male  4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male  5/15/2012         6:24 PM  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# 1                 True                   NaN
# ...

# %% [markdown]
# 3) Se não tem informações de "Team", atribua o valor "Sales"

# %%
# Atribuindo valor Sales onde Team é nulo
before = dados

dados['Team'].fillna('Sales', inplace=True)

# %% [markdown]
# 4) Atribua "Unknown" onde o First Name é nulo

# %%
# Atribuindo valor Unknown onde First Name é nulo
dados['First Name'].fillna('Unknown', inplace=True)

# %% [markdown]
# ## Agora vamos verificar se sobraram valores nulos!!

# %%
dados.isnull().any()
# Out:
# First Name           False
# Gender               False
# Start Date           False
# Last Login Time      False
# Salary               False
# Bonus %              False
# Senior Management    False
# Team                 False
# dtype: bool

# %% [markdown]
# ## Vamos visualizar o total de registros após as correções

# %%
dados.count()
# Out:
# First Name           855
# Gender               855
# Start Date           855
# Last Login Time      855
# Salary               855
# Bonus %              855
# Senior Management    855
# Team                 855
# dtype: int64

# %%
len(dados)

# %% [markdown]
# # Vamos visualizar os nossos dados

# %% [markdown]
# ## Utilizaremos a biblioteca de visualização Seaborn, que é uma extensão mais bonita do Matplotlib. Execute o código abaixo para importar a biblioteca.

# %%
import seaborn as sns
sns.set_theme()

# %% [markdown]
# ## Distribuição de gênero

# %%
dados.groupby(['Gender']).sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-793394d72bab> in <cell line: 1>()
# ----> 1 dados.groupby(['Gender']).sum()
#
# NameError: name 'dados' is not defined

# %%
# dados.groupby(['Gender']).sum(numeric_only=True)
# Out:
#           Salary   Bonus %
# Gender
# Female  38800311  4306.127
# Male    38660604  4392.570

# %% [markdown]
# ## Visualizamos nossos dados em gráfico de pizza

# %%
dados.groupby(['Gender']).sum().plot(kind='pie', y='Salary', autopct='%1.0f%%');
# Out:
# <ipython-input-65-4793a0aa7382>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   dados.groupby(['Gender']).sum().plot(kind='pie', y='Salary', autopct='%1.0f%%');

# %% [markdown]
# # Vamos visualizar a densidade dos dados usando o distplot

# %%
female = dados[dados['Gender'] == 'Female']
male = dados[dados['Gender'] == 'Male']

# %%
sns.displot(
    female['Salary'],
    kde=True,
    stat="density",
    kde_kws=dict(cut=3)
);

# %% [markdown]
# ## Vamos ver o sumário estatístico dos dados de Salário

# %%
dados['Salary'].describe()
# Out:
# count      1000.000000
# mean      90662.181000
# std       32923.693342
# min       35013.000000
# 25%       62613.000000
# 50%       90428.000000
# 75%      118740.250000
# max      149908.000000
# Name: Salary, dtype: float64

# %%
dados.plot.hist(x='Salary', bins=3)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# # Vamos praticar sobre os dados do IGM-CFA

# %% [markdown]
# # 1 - Leia o arquivo CSV contendo os dados do IGM.

# %% [markdown]
# Sobre o conjunto de dados:
#
# Lançado em 2016, o Índice de Governança Municipal (IGM-CFA) consiste em uma métrica da governança pública nos municípios brasileiros a partir de três dimensões: Finanças, Gestão e Desempenho.
#
# https://www.ipm.com.br/noticias/administracao-geral-noticias/indice-de-governanca-municipal-2021-clientes-ipm-sao-destaque-no-brasil/#:~:text=Lan%C3%A7ado%20em%202016%2C%20o%20%C3%8Dndice,%3A%20Finan%C3%A7as%2C%20Gest%C3%A3o%20e%20Desempenho

# %%
# Execute para ler os dados
import pandas as pd
#dados = pd.read_csv("employees.csv")
url='https://drive.google.com/uc?id=1IJPSBCA5PtirkTjw831LxtWSnsjXUpw5'
dados = pd.read_csv(url,sep=";")

# %%
# Visualização dos dados
dados.head()

# %%
# visualizando os tipos dos dados
dados.dtypes
# Out:
# regiao                         object
# estado                         object
# municipio                      object
# codigo_mun                      int64
# capital                         int64
# porte                          object
# populacao                      object
# area                           object
# densidade_dem                  object
# pib                            object
# pib_pc                         object
# participacao_transf_receita    object
# servidores                     object
# comissionados                  object
# comissionados_por_servidor     object
# perc_pop_econ_ativa            object
# taxa_empreendedorismo          object
# anos_estudo_empreendedor       object
# jornada_trabalho               object
# gasto_pc_saude                 object
# hab_p_medico                   object
# exp_vida                       object
# gasto_pc_educacao              object
# exp_anos_estudo                object
# nota_ciencias                  object
# ...

# %%
# Atribuição dos dados para uma nova variável
df = dados

# %% [markdown]
# # 2 - Realize a conversão das colunas area, pib e idhm para o tipo float. Obtenha a média dos valores de cada coluna. Em seguida, realize uma nova importação dos dados, de forma a utilizar o caractere , como separador decimal.

# %%
pd.set_option('display.float_format', lambda x: f'{x:.2f}')

# %%
dados = pd.read_csv(url,sep=";", decimal=",")

# %%
# Outra forma de fazer a transformação para float
(df.
    assign(**{col: df[col]
        .str.replace(',','.')
        .astype(float) for col in [
            'area','pib','idhm'
        ]}
    ).agg('mean', numeric_only=True)
)
# Out:
# codigo_mun    3.253591e+06
# capital       4.847397e-03
# area          1.526532e+03
# pib           9.544801e+05
# idhm          5.186256e-01
# dtype: float64

# %% [markdown]
# # Importação dos dados já transformados

# %%
dados = pd.read_csv(url,sep=";")

# %% [markdown]
# # 3 - Crie um novo DataFrame com as colunas estados, municipio e idhm. Adicione neste novo dataframe uma coluna chamada classe, onde esta irá indicar a classe do município de acordo com o seu IDH. Deverão ser seguidas as regras abaixo:
#
# - Igual ou acima de 0,850: A;
# - Entre 0,750 (inclusive) e 0,850: B;
# - Entre 0,650 (inclusive) e 0,750: C;
# - Entre 0,550 (inclusive) e 0,650: D;
# - Entre 0,450 (inclusive) e 0,550: E;
# - Abaixo de 0,450: F.

# %%
df = dados[["estado", "municipio","idhm"]].copy()

# %% [markdown]
# ## Usando pd.cut para separar as classes

# %%
df = (df.
    assign(
        classe = pd.cut(
            x=df['idhm'],
            bins=[0, 0.45, 0.55, 0.65, 0.75, 0.85, 1],
            labels=['F', 'E', 'D', 'C', 'B', 'A'],
            right=False
        )
    )
)

# %%
df.head()

# %% [markdown]
# # 4 - Utilizando ainda o Dataframe criado na questão anterior, plote um gráfico exibindo a quantidade de municípios por cada classe.

# %%
import matplotlib.pyplot as plt

# %%
df.classe.value_counts().plot(kind='bar');

# %%
df.groupby('classe').count()["estado"]

# %% [markdown]
# # 5 - Utilizando ainda o Dataframe criado na questão 3, considerando os estados dos municípios de classe A, existe algum município de classe C pertencente a estes mesmos estados? Se sim, exiba.

# %%
estados_classe_a = df[df["classe"] == "A"]["estado"].value_counts().index
estados_classe_a

# %%
df[(df["classe"] == "C") & (df['estado'].isin(estados_classe_a))]

# %% [markdown]
# # 6 - Qual a média da coluna idhm para cada estado?

# %%
df.groupby("estado")["idhm"].mean().reset_index()

# %% [markdown]
# # 7 - Plote um gráfico do tipo box plot, descrevendo assim a distribuição do valor da coluna idhm por região.

# %%
dados.boxplot(column="idhm", by="regiao")
plt.show()

# %% [markdown]
# # 8 - Existem municípios de médio porte que também são capitais? Se sim, liste-os. Além disso, liste os 10 municípios de médio porte mais populosos, gerando também uma visualização de pizza utilizando a população.

# %%
set(dados.porte)

# %%
dados[(dados["porte"] == "Médio porte") & dados['capital'] == 1]
